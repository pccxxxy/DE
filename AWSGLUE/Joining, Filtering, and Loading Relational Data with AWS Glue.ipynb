# %% [markdown]
# # Joining, Filtering, and Loading Relational Data with AWS Glue
#
# This example shows how to do joins and filters with transforms entirely on DynamicFrames.
#
# ### 1. Crawl our sample dataset
#
# The dataset we'll be using in this example was downloaded from the [EveryPolitician](http://everypolitician.org)
# website into our sample-dataset bucket in S3, at:
#
#     s3://awsglue-datasets/examples/us-legislators.
#
# It contains data in JSON format about United States legislators and the seats they have held
# in the the House of Representatives and the Senate.
#
# For purposes of our example code, we are assuming that you have created an AWS S3 target bucket and folder,
# which we refer to here as `s3://glue-sample-target/output-dir/`.
#
# The first step is to crawl this data and put the results into a database called `legislators`
# in your Data Catalog, as described [here in the Developer Guide](http://docs.aws.amazon.com/glue/latest/dg/console-crawlers.html).
# The crawler will create the following tables in the `legislators` database:
#
#  - `persons_json`
#  - `memberships_json`
#  - `organizations_json`
#  - `events_json`
#  - `areas_json`
#  - `countries_r_json`
#
# This is a semi-normalized collection of tables containing legislators and their histories.
#
# ### 2. Getting started
#
# We will write a script that:
#
# 1. Combines persons, organizations, and membership histories into a single legislator
#    history data set. This is often referred to as de-normalization.
# 2. Separates out the senators from the representatives.
# 3. Writes each of these out to separate parquet files for later analysis.
#
# Begin by running some boilerplate to import the AWS Glue libraries we'll need and set up a single `GlueContext`.

# %%
import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

glueContext = GlueContext(SparkContext.getOrCreate())
# Out:
# Welcome to the Glue Interactive Sessions Kernel
# For more information on available magic commands, please type %help in any new cell.
#
# Please view our Getting Started page to access the most up-to-date information on the Interactive Sessions kernel: https://docs.aws.amazon.com/glue/latest/dg/interactive-sessions.html
# Installed kernel version: 1.0.5
# Trying to create a Glue session for the kernel.
# Session Type: glueetl
# Session ID: 0dfa34ae-ac9e-4a45-945e-ad418d881dd4
# Applying the following default arguments:
# --glue_kernel_version 1.0.5
# --enable-glue-datacatalog true
# Waiting for session 0dfa34ae-ac9e-4a45-945e-ad418d881dd4 to get into ready status...
# Session 0dfa34ae-ac9e-4a45-945e-ad418d881dd4 has been created.

# %% [markdown]
# ### 3. Checking the schemas that the crawler identified
#
# Next, you can easily examine the schemas that the crawler recorded in the Data Catalog. For example,
# to see the schema of the `persons_json` table, run the following code:

# %%
df = spark.read.json("s3://jrbutbucketsrc/areas/")

# %%
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- identifiers: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- identifier: string (nullable = true)
#  |    |    |-- scheme: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- other_names: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- note: string (nullable = true)
#  |-- type: string (nullable = true)

# %%
persons = glueContext.create_dynamic_frame.from_catalog(database="sampledb", table_name="persons")
print("Count: " + str(persons.count()))
persons.printSchema()
# Out:
# Count: 1961
# root
# |-- family_name: string
# |-- name: string
# |-- links: array
# |    |-- element: struct
# |    |    |-- note: string
# |    |    |-- url: string
# |-- gender: string
# |-- image: string
# |-- identifiers: array
# |    |-- element: struct
# |    |    |-- scheme: string
# |    |    |-- identifier: string
# |-- other_names: array
# |    |-- element: struct
# |    |    |-- lang: string
# |    |    |-- note: string
# |    |    |-- name: string
# |-- sort_name: string
# |-- images: array
# |    |-- element: struct
# |    |    |-- url: string
# |-- given_name: string
# |-- birth_date: string
# |-- id: string
# |-- contact_details: array
# |    |-- element: struct
# |    |    |-- type: string
# |    |    |-- value: string
# |-- death_date: string

# %% [markdown]
# Each person in the table is a member of some congressional body.
#
# Look at the schema of the `memberships_json` table:

# %%
memberships = glueContext.create_dynamic_frame.from_catalog(database="sampledb", table_name="memberships")
print("Count: " + str(memberships.count()))
memberships.printSchema()
# Out:
# Count: 10439
# root
# |-- area_id: string
# |-- on_behalf_of_id: string
# |-- organization_id: string
# |-- role: string
# |-- person_id: string
# |-- legislative_period_id: string
# |-- start_date: string
# |-- end_date: string

# %% [markdown]
# Organizations are parties and the two chambers of congress, the Senate and House.
# Look at the schema of the `organizations_json` table:

# %%
orgs = glueContext.create_dynamic_frame.from_catalog(database="sampledb", table_name="organizations")
print("Count: " + str(orgs.count()))
orgs.printSchema()
# Out:
# Count: 13
# root
# |-- identifiers: array
# |    |-- element: struct
# |    |    |-- scheme: string
# |    |    |-- identifier: string
# |-- other_names: array
# |    |-- element: struct
# |    |    |-- lang: string
# |    |    |-- note: string
# |    |    |-- name: string
# |-- id: string
# |-- classification: string
# |-- name: string
# |-- links: array
# |    |-- element: struct
# |    |    |-- note: string
# |    |    |-- url: string
# |-- image: string
# |-- seats: int
# |-- type: string

# %%
orgs.show()
# Out:
# {"identifiers": [{"scheme": "wikidata", "identifier": "Q3682992"}], "other_names": [{"lang": "en", "note": "multilingual", "name": "At-large"}, {"lang": "it", "note": "multilingual", "name": "Collegio unico"}, {"lang": "fr", "note": "multilingual", "name": "scrutin plurinominal"}, {"lang": "zh", "note": "multilingual", "name": "溫市的全體選民選出"}, {"lang": "it", "note": "multilingual", "name": "Collegio unico nazionale"}], "id": "party/al", "classification": "party", "name": "AL"}
# {"classification": "party", "links": [{"note": "website", "url": "http://www.democrats.org/"}], "image": "https://upload.wikimedia.org/wikipedia/commons/7/73/US_Democratic_Party_Logo.svg", "identifiers": [{"scheme": "wikidata", "identifier": "Q29552"}], "other_names": [{"lang": "zh", "note": "multilingual", "name": "民主党"}, {"lang": "jv", "note": "multilingual", "name": "Democratic Party"}, {"lang": "eu", "note": "multilingual", "name": "Ameriketako Estatu Batuetako Alderdi Demokrata"}, {"lang": "pl", "note": "multilingual", "name": "Partia Demokratyczna"}, {"lang": "bs", "note": "multilingual", "name": "Demokratska stranka"}, {"lang": "es", "note": "multilingual", "name": "Partido Demócrata"}, {"lang": "ta", "note": "multilingual", "name": "மக்களாட்சிக் கட்சி"}, {"lang": "oc", "note": "multilingual", "name": "Partit Democrata"}, {"lang": "ms", "note": "multilingual", "name": "Parti Demokrat"}, {"lang": "hu", "note": "multilingual", "name": "Demokrata Párt"}, {"lang": "et", "note": "multilingual", "name": "Demokraatlik Partei"}, {"lang": "br", "note": "multilingual", "name": "Strollad Demokratel"}, {"lang": "sq", "note": "multilingual", "name": "Partia Demokratike"}, {"lang": "el", "note": "multilingual", "name": "Δημοκρατικό Κόμμα των ΗΠΑ"}, {"lang": "am", "note": "multilingual", "name": "ዴሞክራቲክ ፓርቲ"}, {"lang": "bcl", "note": "multilingual", "name": "Partido Demokrata kan Estados Unidos"}, {"lang": "ga", "note": "multilingual", "name": "Páirtí Daonlathach"}, {"lang": "sv", "note": "multilingual", "name": "Demokratiska partiet"}, {"lang": "nl", "note": "multilingual", "name": "Democratische Partij"}, {"lang": "ar", "note": "multilingual", "name": "الحزب الديمقراطي الأمريكي"}, {"lang": "pt", "note": "multilingual", "name": "Partido Democrata"}, {"lang": "is", "note": "multilingual", "name": "Demókrataflokkurinn"}, {"lang": "eo", "note": "multilingual", "name": "Demokrata Partio"}, {"lang": "yi", "note": "multilingual", "name": "דעמאקראטישע פארטיי"}, {"lang": "ru", "note": "multilingual", "name": "Демократическая партия"}, {"lang": "sr", "note": "multilingual", "name": "Демократска странка"}, {"lang": "ast", "note": "multilingual", "name": "Partíu Demócrata de los Estaos Xuníos"}, {"lang": "tr", "note": "multilingual", "name": "Demokratik Parti"}, {"lang": "fi", "note": "multilingual", "name": "Yhdysvaltain demokraattinen puolue"}, {"lang": "uk", "note": "multilingual", "name": "Демократична партія США"}, {"lang": "be-tarask", "note": "multilingual", "name": "Дэмакратычная партыя"}, {"lang": "nn", "note": "multilingual", "name": "Det demokratiske partiet i USA"}, {"lang": "sco", "note": "multilingual", "name": "Democratic Pairty"}, {"lang": "az", "note": "multilingual", "name": "ABŞ Demokrat Partiyası"}, {"lang": "hr", "note": "multilingual", "name": "Demokratska stranka"}, {"lang": "da", "note": "multilingual", "name": "Demokratiske parti"}, {"lang": "nan", "note": "multilingual", "name": "Bîn-chú Tóng"}, {"lang": "he", "note": "multilingual", "name": "המפלגה הדמוקרטית"}, {"lang": "ko", "note": "multilingual", "name": "민주당"}, {"lang": "fr", "note": "multilingual", "name": "Parti démocrate"}, {"lang": "arz", "note": "multilingual", "name": "الحزب الديموقراطى فى امريكا"}, {"lang": "be", "note": "multilingual", "name": "Дэмакратычная партыя ЗША"}, {"lang": "yo", "note": "multilingual", "name": "Ẹgbẹ́ Dẹmọkrátíkì"}, {"lang": "lv", "note": "multilingual", "name": "ASV Demokrātu partija"}, {"lang": "it", "note": "multilingual", "name": "Partito Democratico"}, {"lang": "gl", "note": "multilingual", "name": "Partido Demócrata"}, {"lang": "id", "note": "multilingual", "name": "Partai Demokrat"}, {"lang": "de", "note": "multilingual", "name": "Demokratische Partei"}, {"lang": "ja", "note": "multilingual", "name": "民主党"}, {"lang": "ml", "note": "multilingual", "name": "ഡെമോക്രാറ്റിക് പാർട്ടി"}, {"lang": "vi", "note": "multilingual", "name": "Đảng Dân chủ"}, {"lang": "yue", "note": "multilingual", "name": "美國民主黨"}, {"lang": "en", "note": "m ...
# {"classification": "party", "links": [{"note": "website", "url": "http://www.liberalparty.org/"}], "identifiers": [{"scheme": "wikidata", "identifier": "Q6540770"}], "other_names": [{"lang": "en", "note": "multilingual", "name": "Liberal Party of New York"}, {"lang": "sv", "note": "multilingual", "name": "Liberala partiet i New York"}, {"lang": "es", "note": "multilingual", "name": "Partido Liberal de Nueva York"}, {"lang": "fr", "note": "multilingual", "name": "Parti libéral de New York"}, {"lang": "zh", "note": "multilingual", "name": "Liberal Party of New York（英文）"}, {"lang": "ja", "note": "multilingual", "name": "ニューヨーク自由党"}, {"lang": "zh", "note": "multilingual", "name": "紐約自由黨"}, {"lang": "ja", "note": "multilingual", "name": "自由党"}], "id": "party/democrat-liberal", "name": "Democrat-Liberal"}
# {"name": "House of Representatives", "classification": "legislature", "identifiers": [{"scheme": "wikidata", "identifier": "Q11701"}], "seats": 435, "type": "lower house", "id": "d56acebe-8fdc-47bc-8b53-20170a3214bc"}
# {"identifiers": [{"scheme": "wikidata", "identifier": "Q327591"}], "other_names": [{"lang": "zh-hans", "note": "multilingual", "name": "无党籍政治人物"}, {"lang": "zh-hant", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "zh-hk", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "zh-cn", "note": "multilingual", "name": "无党籍政治人物"}, {"lang": "zh-sg", "note": "multilingual", "name": "无党籍政治人物"}, {"lang": "zh-tw", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "fr", "note": "multilingual", "name": "Sans étiquette"}, {"lang": "ko", "note": "multilingual", "name": "무소속"}, {"lang": "arz", "note": "multilingual", "name": "سياسى مستقل"}, {"lang": "es", "note": "multilingual", "name": "Candidato independiente"}, {"lang": "ta", "note": "multilingual", "name": "சுயேட்சை"}, {"lang": "de", "note": "multilingual", "name": "Parteiloser"}, {"lang": "id", "note": "multilingual", "name": "Independen"}, {"lang": "ja", "note": "multilingual", "name": "無所属"}, {"lang": "el", "note": "multilingual", "name": "ανεξάρτητος"}, {"lang": "en", "note": "multilingual", "name": "independent politician"}, {"lang": "yue", "note": "multilingual", "name": "獨立人士"}, {"lang": "nl", "note": "multilingual", "name": "onafhankelijk politicus"}, {"lang": "sv", "note": "multilingual", "name": "Partilös"}, {"lang": "ar", "note": "multilingual", "name": "سياسي مستقل"}, {"lang": "pt", "note": "multilingual", "name": "político sem partido"}, {"lang": "ru", "note": "multilingual", "name": "независимый"}, {"lang": "mn", "note": "multilingual", "name": "Бие даагч"}, {"lang": "sr-ec", "note": "multilingual", "name": "независни политичар"}, {"lang": "tr", "note": "multilingual", "name": "Bağımsız siyasetçi"}, {"lang": "ro", "note": "multilingual", "name": "politician independent"}, {"lang": "ca", "note": "multilingual", "name": "polític independent"}, {"lang": "fi", "note": "multilingual", "name": "Sitoutumaton"}, {"lang": "cy", "note": "multilingual", "name": "Annibynnwr"}, {"lang": "ur", "note": "multilingual", "name": "آزاد"}, {"lang": "az", "note": "multilingual", "name": "Partiyasız"}, {"lang": "da", "note": "multilingual", "name": "løsgænger"}, {"lang": "zh", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "sr", "note": "multilingual", "name": "независни политичар"}, {"lang": "fa", "note": "multilingual", "name": "کنشگر سیاسی مستقل"}, {"lang": "war", "note": "multilingual", "name": "Independente"}, {"lang": "oc", "note": "multilingual", "name": "Independent"}, {"lang": "sr-el", "note": "multilingual", "name": "nezavisni političar"}, {"lang": "it", "note": "multilingual", "name": "indipendente"}, {"lang": "be", "note": "multilingual", "name": "Беспартыйны"}, {"lang": "pl", "note": "multilingual", "name": "polityk niezrzeszony"}, {"lang": "mr", "note": "multilingual", "name": "अपक्ष"}, {"lang": "be-tarask", "note": "multilingual", "name": "Беспартыйны"}, {"lang": "he", "note": "multilingual", "name": "פוליטיקאי עצמאי"}, {"lang": "nb", "note": "multilingual", "name": "partiløs"}, {"lang": "cs", "note": "multilingual", "name": "nezávislý"}, {"lang": "hu", "note": "multilingual", "name": "független politikus"}, {"lang": "eo", "note": "multilingual", "name": "Sendependa"}, {"lang": "hi", "note": "multilingual", "name": "निर्दलीय"}, {"lang": "sh", "note": "multilingual", "name": "Nezavisni"}, {"lang": "sco", "note": "multilingual", "name": "independent politeecian"}, {"lang": "sk", "note": "multilingual", "name": "Nezávislý politik"}, {"lang": "hak", "note": "multilingual", "name": "Mò-tóng-sit"}, {"lang": "th", "note": "multilingual", "name": "นักการเมืองอิสระ"}, {"lang": "uk", "note": "multilingual", "name": "Незалежний політик"}, {"lang": "sd", "note": "multilingual", "name": "آزاد"}, {"lang": "la", "note": "multilingual", "name": "Politicus nullius factionis"}, {"lang": "nan", "note": "multilingual", "name": "Bû-tóng-che̍k"}, {"lang": "tg", "note": "multilingual", "name": "сиёсатмадори мустақил"}, {"lang": "zh-mo", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang" ...
# {"classification": "party", "links": [{"note": "website", "url": "http://www.pnppr.com"}], "image": "https://upload.wikimedia.org/wikipedia/commons/7/75/PNP.logo.png", "identifiers": [{"scheme": "wikidata", "identifier": "Q1076562"}], "other_names": [{"lang": "de", "note": "multilingual", "name": "Partido Nuevo Progresista"}, {"lang": "ko", "note": "multilingual", "name": "푸에르토리코 진보신당"}, {"lang": "es", "note": "multilingual", "name": "Partido Nuevo Progresista"}, {"lang": "en", "note": "multilingual", "name": "New Progressive Party of Puerto Rico"}, {"lang": "ar", "note": "multilingual", "name": "الحزب الجديد التقدمي"}, {"lang": "it", "note": "multilingual", "name": "Nuovo Partito Progressista"}, {"lang": "pt", "note": "multilingual", "name": "Partido Novo Progressista"}, {"lang": "zh", "note": "multilingual", "name": "新进步党"}, {"lang": "ru", "note": "multilingual", "name": "Новая прогрессивная партия Пуэрто-Рико"}, {"lang": "nl", "note": "multilingual", "name": "Nieuw Progressieve Partij van Puerto Rico"}, {"lang": "ca", "note": "multilingual", "name": "Partit Nou Progressista"}, {"lang": "nb", "note": "multilingual", "name": "Partido Nuevo Progresista (Puerto Rico)"}, {"lang": "ja", "note": "multilingual", "name": "プエルトリコ新進歩党"}, {"lang": "pt-br", "note": "multilingual", "name": "Partido Novo Progressista"}, {"lang": "de", "note": "multilingual", "name": "Partido Nuevo Progresista de Puerto Rico"}, {"lang": "ko", "note": "multilingual", "name": "푸에르토리코 신진보당"}, {"lang": "it", "note": "multilingual", "name": "Nuovo Partito Progressista di Porto Rico"}, {"lang": "en", "note": "multilingual", "name": "pnp"}, {"lang": "ca", "note": "multilingual", "name": "PNP"}, {"lang": "zh", "note": "multilingual", "name": "New Progressive Party of Puerto Rico（英文）"}, {"lang": "pt", "note": "multilingual", "name": "PNP"}, {"lang": "pt", "note": "multilingual", "name": "pnp"}, {"lang": "pt", "note": "multilingual", "name": "Partido Novo Progressista de Porto Rico"}, {"lang": "pt-br", "note": "multilingual", "name": "PNP"}, {"lang": "pt-br", "note": "multilingual", "name": "pnp"}, {"lang": "pt-br", "note": "multilingual", "name": "Partido Novo Progressista de Porto Rico"}], "id": "party/new_progressive", "name": "New Progressive"}
# {"classification": "party", "links": [{"note": "website", "url": "http://www.ppdpr.net/"}], "identifiers": [{"scheme": "wikidata", "identifier": "Q199319"}], "other_names": [{"lang": "es", "note": "multilingual", "name": "Partido Popular Democrático"}, {"lang": "it", "note": "multilingual", "name": "Partito Popolare Democratico"}, {"lang": "fr", "note": "multilingual", "name": "Parti populaire démocrate"}, {"lang": "en", "note": "multilingual", "name": "Popular Democratic Party"}, {"lang": "bs", "note": "multilingual", "name": "Narodna demokratska stranka (Portoriko)"}, {"lang": "zh", "note": "multilingual", "name": "人民民主党"}, {"lang": "ru", "note": "multilingual", "name": "Народно-демократическая партия"}, {"lang": "nl", "note": "multilingual", "name": "Populaire Democratische Partij"}, {"lang": "de", "note": "multilingual", "name": "Partido Popular Democrático"}, {"lang": "ca", "note": "multilingual", "name": "Partit Popular Democràtic"}, {"lang": "pt", "note": "multilingual", "name": "Partido Popular Democrático"}, {"lang": "ja", "note": "multilingual", "name": "プエルトリコ人民民主党"}, {"lang": "es", "note": "multilingual", "name": "Partido Popular Democratico"}, {"lang": "es", "note": "multilingual", "name": "Partido Popular Democrático de Puerto Rico"}, {"lang": "es", "note": "multilingual", "name": "Partido Popular Democratico de Puerto Rico"}, {"lang": "it", "note": "multilingual", "name": "Partito Popolare Democratico di Porto Rico"}, {"lang": "fr", "note": "multilingual", "name": "Parti populaire démocrate de Porto Rico"}, {"lang": "ca", "note": "multilingual", "name": "PPD"}], "id": "party/popular_democrat", "name": "Popular Democrat"}
# {"classification": "party", "links": [{"note": "website", "url": "http://www.gop.com/"}], "image": "https://upload.wikimedia.org/wikipedia/commons/d/d7/Logo-GOP.svg", "identifiers": [{"scheme": "wikidata", "identifier": "Q29468"}], "other_names": [{"lang": "zh", "note": "multilingual", "name": "共和黨"}, {"lang": "eu", "note": "multilingual", "name": "Ameriketako Estatu Batuetako Alderdi Errepublikanoa"}, {"lang": "pl", "note": "multilingual", "name": "Partia Republikańska"}, {"lang": "bs", "note": "multilingual", "name": "Republikanska stranka"}, {"lang": "es", "note": "multilingual", "name": "Partido Republicano"}, {"lang": "ta", "note": "multilingual", "name": "குடியரசுக் கட்சி"}, {"lang": "oc", "note": "multilingual", "name": "Partit Republican"}, {"lang": "ms", "note": "multilingual", "name": "Parti Republikan"}, {"lang": "hu", "note": "multilingual", "name": "Republikánus Párt"}, {"lang": "et", "note": "multilingual", "name": "Vabariiklik Partei"}, {"lang": "br", "note": "multilingual", "name": "Strollad Republikan"}, {"lang": "sq", "note": "multilingual", "name": "Partia Republikane"}, {"lang": "el", "note": "multilingual", "name": "Ρεπουμπλικανικό Κόμμα"}, {"lang": "am", "note": "multilingual", "name": "ሪፐብሊካን ፓርቲ"}, {"lang": "bcl", "note": "multilingual", "name": "Partido Republikano kan Estados Unidos"}, {"lang": "ga", "note": "multilingual", "name": "Páirtí Poblachtach"}, {"lang": "nl", "note": "multilingual", "name": "Republikeinse Partij"}, {"lang": "ar", "note": "multilingual", "name": "الحزب الجمهوري"}, {"lang": "sv", "note": "multilingual", "name": "Republikanska partiet"}, {"lang": "pt", "note": "multilingual", "name": "Partido Republicano"}, {"lang": "is", "note": "multilingual", "name": "Repúblikanaflokkurinn"}, {"lang": "eo", "note": "multilingual", "name": "Respublikana Partio"}, {"lang": "yi", "note": "multilingual", "name": "רעפובליקאנער פארטיי"}, {"lang": "ru", "note": "multilingual", "name": "Республиканская партия"}, {"lang": "sr", "note": "multilingual", "name": "Републиканска странка"}, {"lang": "ast", "note": "multilingual", "name": "Partíu Republicanu de los Estaos Xuníos"}, {"lang": "tr", "note": "multilingual", "name": "Cumhuriyetçi Parti"}, {"lang": "mk", "note": "multilingual", "name": "Републиканска партија"}, {"lang": "fi", "note": "multilingual", "name": "Yhdysvaltain republikaaninen puolue"}, {"lang": "uk", "note": "multilingual", "name": "Республіканська партія США"}, {"lang": "nn", "note": "multilingual", "name": "Det republikanske partiet i USA"}, {"lang": "sco", "note": "multilingual", "name": "Republican Pairty"}, {"lang": "az", "note": "multilingual", "name": "ABŞ Respublikaçılar Partiyası"}, {"lang": "hr", "note": "multilingual", "name": "Republikanska stranka"}, {"lang": "da", "note": "multilingual", "name": "Republikanske parti"}, {"lang": "nan", "note": "multilingual", "name": "Kiōng-hô Tóng"}, {"lang": "vec", "note": "multilingual", "name": "Partito Republicàn"}, {"lang": "be", "note": "multilingual", "name": "Рэспубліканская партыя ЗША"}, {"lang": "he", "note": "multilingual", "name": "המפלגה הרפובליקנית"}, {"lang": "arz", "note": "multilingual", "name": "الحزب الجمهورى فى امريكا"}, {"lang": "ko", "note": "multilingual", "name": "공화당"}, {"lang": "fr", "note": "multilingual", "name": "Parti républicain"}, {"lang": "yo", "note": "multilingual", "name": "Ẹgbẹ́ Rẹ̀públíkánì"}, {"lang": "bar", "note": "multilingual", "name": "Republikånische Påtei"}, {"lang": "lv", "note": "multilingual", "name": "ASV Republikāņu partija"}, {"lang": "it", "note": "multilingual", "name": "Partito Repubblicano"}, {"lang": "gl", "note": "multilingual", "name": "Partido Republicano"}, {"lang": "id", "note": "multilingual", "name": "Partai Republik"}, {"lang": "de", "note": "multilingual", "name": "Republikanische Partei"}, {"lang": "ja", "note": "multilingual", "name": "共和党"}, {"lang": "vi", "note": "multilingual", "name": "Đảng Cộng hòa"}, {"lang": "en", "note": "multilingual", "name": "Republican Party"} ...
# {"classification": "party", "links": [{"note": "website", "url": "http://www.cpnys.org/"}], "identifiers": [{"scheme": "wikidata", "identifier": "Q5163079"}], "other_names": [{"lang": "en", "note": "multilingual", "name": "Conservative Party of New York State"}, {"lang": "de", "note": "multilingual", "name": "Conservative Party of New York State"}, {"lang": "ko", "note": "multilingual", "name": "뉴욕 주 보수당"}, {"lang": "ja", "note": "multilingual", "name": "ニューヨーク州保守党"}, {"lang": "ja", "note": "multilingual", "name": "保守党"}], "id": "party/republican-conservative", "name": "Republican-Conservative"}
# {"classification": "party", "links": [{"note": "website", "url": "http://www.democrats.org/"}], "image": "https://upload.wikimedia.org/wikipedia/commons/7/73/US_Democratic_Party_Logo.svg", "identifiers": [{"scheme": "wikidata", "identifier": "Q29552"}], "other_names": [{"lang": "zh", "note": "multilingual", "name": "民主党"}, {"lang": "jv", "note": "multilingual", "name": "Democratic Party"}, {"lang": "eu", "note": "multilingual", "name": "Ameriketako Estatu Batuetako Alderdi Demokrata"}, {"lang": "pl", "note": "multilingual", "name": "Partia Demokratyczna"}, {"lang": "bs", "note": "multilingual", "name": "Demokratska stranka"}, {"lang": "es", "note": "multilingual", "name": "Partido Demócrata"}, {"lang": "ta", "note": "multilingual", "name": "மக்களாட்சிக் கட்சி"}, {"lang": "oc", "note": "multilingual", "name": "Partit Democrata"}, {"lang": "ms", "note": "multilingual", "name": "Parti Demokrat"}, {"lang": "hu", "note": "multilingual", "name": "Demokrata Párt"}, {"lang": "et", "note": "multilingual", "name": "Demokraatlik Partei"}, {"lang": "br", "note": "multilingual", "name": "Strollad Demokratel"}, {"lang": "sq", "note": "multilingual", "name": "Partia Demokratike"}, {"lang": "el", "note": "multilingual", "name": "Δημοκρατικό Κόμμα των ΗΠΑ"}, {"lang": "am", "note": "multilingual", "name": "ዴሞክራቲክ ፓርቲ"}, {"lang": "bcl", "note": "multilingual", "name": "Partido Demokrata kan Estados Unidos"}, {"lang": "ga", "note": "multilingual", "name": "Páirtí Daonlathach"}, {"lang": "sv", "note": "multilingual", "name": "Demokratiska partiet"}, {"lang": "nl", "note": "multilingual", "name": "Democratische Partij"}, {"lang": "ar", "note": "multilingual", "name": "الحزب الديمقراطي الأمريكي"}, {"lang": "pt", "note": "multilingual", "name": "Partido Democrata"}, {"lang": "is", "note": "multilingual", "name": "Demókrataflokkurinn"}, {"lang": "eo", "note": "multilingual", "name": "Demokrata Partio"}, {"lang": "yi", "note": "multilingual", "name": "דעמאקראטישע פארטיי"}, {"lang": "ru", "note": "multilingual", "name": "Демократическая партия"}, {"lang": "sr", "note": "multilingual", "name": "Демократска странка"}, {"lang": "ast", "note": "multilingual", "name": "Partíu Demócrata de los Estaos Xuníos"}, {"lang": "tr", "note": "multilingual", "name": "Demokratik Parti"}, {"lang": "fi", "note": "multilingual", "name": "Yhdysvaltain demokraattinen puolue"}, {"lang": "uk", "note": "multilingual", "name": "Демократична партія США"}, {"lang": "be-tarask", "note": "multilingual", "name": "Дэмакратычная партыя"}, {"lang": "nn", "note": "multilingual", "name": "Det demokratiske partiet i USA"}, {"lang": "sco", "note": "multilingual", "name": "Democratic Pairty"}, {"lang": "az", "note": "multilingual", "name": "ABŞ Demokrat Partiyası"}, {"lang": "hr", "note": "multilingual", "name": "Demokratska stranka"}, {"lang": "da", "note": "multilingual", "name": "Demokratiske parti"}, {"lang": "nan", "note": "multilingual", "name": "Bîn-chú Tóng"}, {"lang": "he", "note": "multilingual", "name": "המפלגה הדמוקרטית"}, {"lang": "ko", "note": "multilingual", "name": "민주당"}, {"lang": "fr", "note": "multilingual", "name": "Parti démocrate"}, {"lang": "arz", "note": "multilingual", "name": "الحزب الديموقراطى فى امريكا"}, {"lang": "be", "note": "multilingual", "name": "Дэмакратычная партыя ЗША"}, {"lang": "yo", "note": "multilingual", "name": "Ẹgbẹ́ Dẹmọkrátíkì"}, {"lang": "lv", "note": "multilingual", "name": "ASV Demokrātu partija"}, {"lang": "it", "note": "multilingual", "name": "Partito Democratico"}, {"lang": "gl", "note": "multilingual", "name": "Partido Demócrata"}, {"lang": "id", "note": "multilingual", "name": "Partai Demokrat"}, {"lang": "de", "note": "multilingual", "name": "Demokratische Partei"}, {"lang": "ja", "note": "multilingual", "name": "民主党"}, {"lang": "ml", "note": "multilingual", "name": "ഡെമോക്രാറ്റിക് പാർട്ടി"}, {"lang": "vi", "note": "multilingual", "name": "Đảng Dân chủ"}, {"lang": "yue", "note": "multilingual", "name": "美國民主黨"}, {"lang": "en", "note": "m ...
# {"identifiers": [{"scheme": "wikidata", "identifier": "Q327591"}], "other_names": [{"lang": "zh-hans", "note": "multilingual", "name": "无党籍政治人物"}, {"lang": "zh-hant", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "zh-hk", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "zh-cn", "note": "multilingual", "name": "无党籍政治人物"}, {"lang": "zh-sg", "note": "multilingual", "name": "无党籍政治人物"}, {"lang": "zh-tw", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "fr", "note": "multilingual", "name": "Sans étiquette"}, {"lang": "ko", "note": "multilingual", "name": "무소속"}, {"lang": "arz", "note": "multilingual", "name": "سياسى مستقل"}, {"lang": "es", "note": "multilingual", "name": "Candidato independiente"}, {"lang": "ta", "note": "multilingual", "name": "சுயேட்சை"}, {"lang": "de", "note": "multilingual", "name": "Parteiloser"}, {"lang": "id", "note": "multilingual", "name": "Independen"}, {"lang": "ja", "note": "multilingual", "name": "無所属"}, {"lang": "el", "note": "multilingual", "name": "ανεξάρτητος"}, {"lang": "en", "note": "multilingual", "name": "independent politician"}, {"lang": "yue", "note": "multilingual", "name": "獨立人士"}, {"lang": "nl", "note": "multilingual", "name": "onafhankelijk politicus"}, {"lang": "sv", "note": "multilingual", "name": "partilös"}, {"lang": "ar", "note": "multilingual", "name": "سياسي مستقل"}, {"lang": "pt", "note": "multilingual", "name": "político sem partido"}, {"lang": "ru", "note": "multilingual", "name": "независимый"}, {"lang": "mn", "note": "multilingual", "name": "Бие даагч"}, {"lang": "sr-ec", "note": "multilingual", "name": "независни политичар"}, {"lang": "tr", "note": "multilingual", "name": "Bağımsız siyasetçi"}, {"lang": "ro", "note": "multilingual", "name": "politician independent"}, {"lang": "ca", "note": "multilingual", "name": "polític independent"}, {"lang": "fi", "note": "multilingual", "name": "sitoutumaton"}, {"lang": "cy", "note": "multilingual", "name": "Annibynnwr"}, {"lang": "ur", "note": "multilingual", "name": "آزاد"}, {"lang": "az", "note": "multilingual", "name": "Partiyasız"}, {"lang": "da", "note": "multilingual", "name": "løsgænger"}, {"lang": "zh", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang": "sr", "note": "multilingual", "name": "независни политичар"}, {"lang": "fa", "note": "multilingual", "name": "کنشگر سیاسی مستقل"}, {"lang": "war", "note": "multilingual", "name": "Independente"}, {"lang": "oc", "note": "multilingual", "name": "Independent"}, {"lang": "sr-el", "note": "multilingual", "name": "nezavisni političar"}, {"lang": "it", "note": "multilingual", "name": "indipendente"}, {"lang": "be", "note": "multilingual", "name": "Беспартыйны"}, {"lang": "pl", "note": "multilingual", "name": "polityk niezrzeszony"}, {"lang": "mr", "note": "multilingual", "name": "अपक्ष"}, {"lang": "be-tarask", "note": "multilingual", "name": "Беспартыйны"}, {"lang": "he", "note": "multilingual", "name": "פוליטיקאי עצמאי"}, {"lang": "nb", "note": "multilingual", "name": "partiløs"}, {"lang": "cs", "note": "multilingual", "name": "nezávislý"}, {"lang": "hu", "note": "multilingual", "name": "független politikus"}, {"lang": "eo", "note": "multilingual", "name": "Sendependa"}, {"lang": "hi", "note": "multilingual", "name": "निर्दलीय"}, {"lang": "sh", "note": "multilingual", "name": "Nezavisni"}, {"lang": "sco", "note": "multilingual", "name": "independent politeecian"}, {"lang": "sk", "note": "multilingual", "name": "Nezávislý politik"}, {"lang": "hak", "note": "multilingual", "name": "Mò-tóng-sit"}, {"lang": "th", "note": "multilingual", "name": "นักการเมืองอิสระ"}, {"lang": "uk", "note": "multilingual", "name": "Незалежний політик"}, {"lang": "sd", "note": "multilingual", "name": "آزاد"}, {"lang": "la", "note": "multilingual", "name": "Politicus nullius factionis"}, {"lang": "nan", "note": "multilingual", "name": "Bû-tóng-che̍k"}, {"lang": "tg", "note": "multilingual", "name": "сиёсатмадори мустақил"}, {"lang": "zh-mo", "note": "multilingual", "name": "無黨籍政治人物"}, {"lang" ...
# {"classification": "party", "links": [{"note": "website", "url": "http://www.gop.com/"}], "image": "https://upload.wikimedia.org/wikipedia/commons/d/d7/Logo-GOP.svg", "identifiers": [{"scheme": "wikidata", "identifier": "Q29468"}], "other_names": [{"lang": "zh", "note": "multilingual", "name": "共和黨"}, {"lang": "eu", "note": "multilingual", "name": "Ameriketako Estatu Batuetako Alderdi Errepublikanoa"}, {"lang": "pl", "note": "multilingual", "name": "Partia Republikańska"}, {"lang": "bs", "note": "multilingual", "name": "Republikanska stranka"}, {"lang": "es", "note": "multilingual", "name": "Partido Republicano"}, {"lang": "ta", "note": "multilingual", "name": "குடியரசுக் கட்சி"}, {"lang": "oc", "note": "multilingual", "name": "Partit Republican"}, {"lang": "ms", "note": "multilingual", "name": "Parti Republikan"}, {"lang": "hu", "note": "multilingual", "name": "Republikánus Párt"}, {"lang": "et", "note": "multilingual", "name": "Vabariiklik Partei"}, {"lang": "br", "note": "multilingual", "name": "Strollad Republikan"}, {"lang": "sq", "note": "multilingual", "name": "Partia Republikane"}, {"lang": "el", "note": "multilingual", "name": "Ρεπουμπλικανικό Κόμμα"}, {"lang": "am", "note": "multilingual", "name": "ሪፐብሊካን ፓርቲ"}, {"lang": "bcl", "note": "multilingual", "name": "Partido Republikano kan Estados Unidos"}, {"lang": "ga", "note": "multilingual", "name": "Páirtí Poblachtach"}, {"lang": "nl", "note": "multilingual", "name": "Republikeinse Partij"}, {"lang": "ar", "note": "multilingual", "name": "الحزب الجمهوري"}, {"lang": "sv", "note": "multilingual", "name": "Republikanska partiet"}, {"lang": "pt", "note": "multilingual", "name": "Partido Republicano"}, {"lang": "is", "note": "multilingual", "name": "Repúblikanaflokkurinn"}, {"lang": "eo", "note": "multilingual", "name": "Respublikana Partio"}, {"lang": "yi", "note": "multilingual", "name": "רעפובליקאנער פארטיי"}, {"lang": "ru", "note": "multilingual", "name": "Республиканская партия"}, {"lang": "sr", "note": "multilingual", "name": "Републиканска странка"}, {"lang": "ast", "note": "multilingual", "name": "Partíu Republicanu de los Estaos Xuníos"}, {"lang": "tr", "note": "multilingual", "name": "Cumhuriyetçi Parti"}, {"lang": "mk", "note": "multilingual", "name": "Републиканска партија"}, {"lang": "fi", "note": "multilingual", "name": "Yhdysvaltain republikaaninen puolue"}, {"lang": "uk", "note": "multilingual", "name": "Республіканська партія США"}, {"lang": "nn", "note": "multilingual", "name": "Det republikanske partiet i USA"}, {"lang": "sco", "note": "multilingual", "name": "Republican Pairty"}, {"lang": "az", "note": "multilingual", "name": "ABŞ Respublikaçılar Partiyası"}, {"lang": "hr", "note": "multilingual", "name": "Republikanska stranka"}, {"lang": "da", "note": "multilingual", "name": "Republikanske parti"}, {"lang": "nan", "note": "multilingual", "name": "Kiōng-hô Tóng"}, {"lang": "vec", "note": "multilingual", "name": "Partito Republicàn"}, {"lang": "be", "note": "multilingual", "name": "Рэспубліканская партыя ЗША"}, {"lang": "he", "note": "multilingual", "name": "המפלגה הרפובליקנית"}, {"lang": "arz", "note": "multilingual", "name": "الحزب الجمهورى فى امريكا"}, {"lang": "ko", "note": "multilingual", "name": "공화당"}, {"lang": "fr", "note": "multilingual", "name": "Parti républicain"}, {"lang": "yo", "note": "multilingual", "name": "Ẹgbẹ́ Rẹ̀públíkánì"}, {"lang": "bar", "note": "multilingual", "name": "Republikånische Påtei"}, {"lang": "lv", "note": "multilingual", "name": "ASV Republikāņu partija"}, {"lang": "it", "note": "multilingual", "name": "Partito Repubblicano"}, {"lang": "gl", "note": "multilingual", "name": "Partido Republicano"}, {"lang": "id", "note": "multilingual", "name": "Partai Republik"}, {"lang": "de", "note": "multilingual", "name": "Republikanische Partei"}, {"lang": "ja", "note": "multilingual", "name": "共和党"}, {"lang": "vi", "note": "multilingual", "name": "Đảng Cộng hòa"}, {"lang": "en", "note": "multilingual", "name": "Republican Party"} ...
# {"name": "Senate", "classification": "legislature", "identifiers": [{"scheme": "wikidata", "identifier": "Q66096"}], "seats": 100, "type": "upper house", "id": "8fa6c3d2-71dc-4788-b9f8-4ca70d5a7d85"}

# %% [markdown]
# ### 4. Filtering
#
# Let's only keep the fields that we want and rename `id` to `org_id`. The dataset is small enough that we can
# look at the whole thing. The `toDF()` converts a DynamicFrame to a Spark DataFrame, so we can apply the
# transforms that already exist in SparkSQL:

# %%
orgs = orgs.drop_fields(['other_names','identifiers']).rename_field('id', 'org_id').rename_field('name', 'org_name')
orgs.toDF().show() #convert Glue dataframe to Spark dataframe
# Out:
# +--------------+--------------------+--------------------+--------------------+--------------------+-----+-----------+
# |classification|              org_id|            org_name|               links|               image|seats|       type|
# +--------------+--------------------+--------------------+--------------------+--------------------+-----+-----------+
# |         party|            party/al|                  AL|                null|                null| null|       null|
# |         party|      party/democrat|            Democrat|[{website, http:/...|https://upload.wi...| null|       null|
# |         party|party/democrat-li...|    Democrat-Liberal|[{website, http:/...|                null| null|       null|
# |   legislature|d56acebe-8fdc-47b...|House of Represen...|                null|                null|  435|lower house|
# |         party|   party/independent|         Independent|                null|                null| null|       null|
# |         party|party/new_progres...|     New Progressive|[{website, http:/...|https://upload.wi...| null|       null|
# |         party|party/popular_dem...|    Popular Democrat|[{website, http:/...|                null| null|       null|
# |         party|    party/republican|          Republican|[{website, http:/...|https://upload.wi...| null|       null|
# |         party|party/republican-...|Republican-Conser...|[{website, http:/...|                null| null|       null|
# |         party|      party/democrat|            Democrat|[{website, http:/...|https://upload.wi...| null|       null|
# |         party|   party/independent|         Independent|                null|                null| null|       null|
# |         party|    party/republican|          Republican|[{website, http:/...|https://upload.wi...| null|       null|
# |   legislature|8fa6c3d2-71dc-478...|              Senate|                null|                null|  100|upper house|
# +--------------+--------------------+--------------------+--------------------+--------------------+-----+-----------+
#
# /opt/amazon/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:127: UserWarning: DataFrame constructor is internal. Do not directly use it.
#   warnings.warn("DataFrame constructor is internal. Do not directly use it.")

# %% [markdown]
# Let's look at the `organizations` that appear in `memberships`:

# %%
memberships.select_fields(['organization_id']).toDF().distinct().show()
# Out:
# +--------------------+
# |     organization_id|
# +--------------------+
# |d56acebe-8fdc-47b...|
# |8fa6c3d2-71dc-478...|
# +--------------------+

# %% [markdown]
# ### 5. Putting it together
#
# Now let's join these relational tables to create one full history table of legislator
# memberships and their correponding organizations, using AWS Glue.
#
#  - First, we join `persons` and `memberships` on `id` and `person_id`.
#  - Next, join the result with orgs on `org_id` and `organization_id`.
#  - Then, drop the redundant fields, `person_id` and `org_id`.
#
# We can do all these operations in one (extended) line of code:

# %%
l_history = Join.apply(orgs,
                       Join.apply(persons, memberships, 'id', 'person_id'),
                       'org_id', 'organization_id').drop_fields(['person_id', 'org_id'])
print("Count: " + str(l_history.count()))
l_history.printSchema()
# Out:
# Count: 10439
# root
# |-- role: string
# |-- seats: int
# |-- org_name: string
# |-- type: string
# |-- links: array
# |    |-- element: struct
# |    |    |-- note: string
# |    |    |-- url: string
# |-- sort_name: string
# |-- area_id: string
# |-- images: array
# |    |-- element: struct
# |    |    |-- url: string
# |-- on_behalf_of_id: string
# |-- other_names: array
# |    |-- element: struct
# |    |    |-- lang: string
# |    |    |-- note: string
# |    |    |-- name: string
# |-- contact_details: array
# |    |-- element: struct
# |    |    |-- type: string
# |    |    |-- value: string
# |-- name: string
# |-- birth_date: string
# |-- organization_id: string
# |-- gender: string
# |-- classification: string
# |-- identifiers: array
# |    |-- element: struct
# |    |    |-- scheme: string
# |    |    |-- identifier: string
# |-- legislative_period_id: string
# |-- given_name: string
# |-- image: string
# |-- family_name: string
# |-- id: string
# |-- end_date: string
# |-- death_date: string
# |-- start_date: string

# %% [markdown]
# Great! We now have the final table that we'd like to use for analysis.
# Let's write it out in a compact, efficient format for analytics, i.e. Parquet,
# that we can run SQL over in AWS Glue, Athena, or Redshift Spectrum.
#
# The following call writes the table across multiple files to support fast parallel
# reads when doing analysis later:

# %%
# Write data into 3 partitions indicated by 3 parquet file
glueContext.write_dynamic_frame.from_options(frame = l_history,
              connection_type = "s3",
              connection_options = {"path": "s3://jrbutbucketdest/new"},
              format = "parquet")
# Out:
# <awsglue.dynamicframe.DynamicFrame object at 0x7fc8658a8670>

# %% [markdown]
# To put all the history data into a single file, we need to convert it to a data frame, repartition it, and
# write it out.

# %%
# Write data into one single partition indicated by 1 parquet file

s_history = l_history.toDF().repartition(1)
s_history.write.parquet('s3://glue-sample-target/output-dir/legislator_single')
# Out:
# Py4JJavaError: An error occurred while calling o162.parquet.
# : java.io.IOException: com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.services.s3.model.AmazonS3Exception: Access Denied (Service: Amazon S3; Status Code: 403; Error Code: AccessDenied; Request ID: 8W8KA608MNNZ5P0R; S3 Extended Request ID: UST2oPfwW2c3tKYHmLPaxCmAcciy/J0TmgNVQLzzy6PHiX3Ts43Cq1f/e/ZZwEaaoC7OkmJRwCY=; Proxy: null), S3 Extended Request ID: UST2oPfwW2c3tKYHmLPaxCmAcciy/J0TmgNVQLzzy6PHiX3Ts43Cq1f/e/ZZwEaaoC7OkmJRwCY=
# 	at com.amazon.ws.emr.hadoop.fs.s3n.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:423)
# 	at com.amazon.ws.emr.hadoop.fs.s3n.Jets3tNativeFileSystemStore.isFolderUsingFolderObject(Jets3tNativeFileSystemStore.java:249)
# 	at com.amazon.ws.emr.hadoop.fs.s3n.Jets3tNativeFileSystemStore.isFolder(Jets3tNativeFileSystemStore.java:212)
# 	at com.amazon.ws.emr.hadoop.fs.s3n.S3NativeFileSystem.getFileStatus(S3NativeFileSystem.java:518)
# 	at org.apache.hadoop.fs.FileSystem.exists(FileSystem.java:1767)
# 	at com.amazon.ws.emr.hadoop.fs.EmrFileSystem.exists(EmrFileSystem.java:402)
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:122)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:113)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:111)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.executeCollect(commands.scala:125)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.$anonfun$applyOrElse$1(QueryExecution.scala:103)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:107)
# 	at org.apache.spark.sql.execution.SQLExecution$.withTracker(SQLExecution.scala:224)
# 	at org.apache.spark.sql.execution.SQLExecution$.executeQuery$1(SQLExecution.scala:114)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$7(SQLExecution.scala:139)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:107)
# 	at org.apache.spark.sql.execution.SQLExecution$.withTracker(SQLExecution.scala:224)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$6(SQLExecution.scala:139)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:245)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$1(SQLExecution.scala:138)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:779)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:68)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:100)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:96)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDownWithPruning$1(TreeNode.scala:615)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:177)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDownWithPruning(TreeNode.scala:615)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDownWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning(AnalysisHelper.scala:267)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning$(AnalysisHelper.scala:263)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:591)
# 	at org.apache.spark.sql.execution.QueryExecution.eagerlyExecuteCommands(QueryExecution.scala:96)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted$lzycompute(QueryExecution.scala:83)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted(QueryExecution.scala:81)
# 	at org.apache.spark.sql.execution.QueryExecution.assertCommandExecuted(QueryExecution.scala:124)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:860)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:390)
# 	at org.apache.spark.sql.DataFrameWriter.saveInternal(DataFrameWriter.scala:363)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:239)
# 	at org.apache.spark.sql.DataFrameWriter.parquet(DataFrameWriter.scala:793)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.services.s3.model.AmazonS3Exception: Access Denied (Service: Amazon S3; Status Code: 403; Error Code: AccessDenied; Request ID: 8W8KA608MNNZ5P0R; S3 Extended Request ID: UST2oPfwW2c3tKYHmLPaxCmAcciy/J0TmgNVQLzzy6PHiX3Ts43Cq1f/e/ZZwEaaoC7OkmJRwCY=; Proxy: null), S3 Extended Request ID: UST2oPfwW2c3tKYHmLPaxCmAcciy/J0TmgNVQLzzy6PHiX3Ts43Cq1f/e/ZZwEaaoC7OkmJRwCY=
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.handleErrorResponse(AmazonHttpClient.java:1879)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.handleServiceErrorResponse(AmazonHttpClient.java:1418)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.executeOneRequest(AmazonHttpClient.java:1387)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.executeHelper(AmazonHttpClient.java:1157)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.doExecute(AmazonHttpClient.java:814)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.executeWithTimer(AmazonHttpClient.java:781)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.execute(AmazonHttpClient.java:755)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutor.access$500(AmazonHttpClient.java:715)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient$RequestExecutionBuilderImpl.execute(AmazonHttpClient.java:697)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient.execute(AmazonHttpClient.java:561)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.http.AmazonHttpClient.execute(AmazonHttpClient.java:541)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.services.s3.AmazonS3Client.invoke(AmazonS3Client.java:5456)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.services.s3.AmazonS3Client.invoke(AmazonS3Client.java:5403)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.services.s3.AmazonS3Client.invoke(AmazonS3Client.java:5397)
# 	at com.amazon.ws.emr.hadoop.fs.shaded.com.amazonaws.services.s3.AmazonS3Client.listObjectsV2(AmazonS3Client.java:971)
# 	at com.amazon.ws.emr.hadoop.fs.s3.lite.call.ListObjectsV2Call.perform(ListObjectsV2Call.java:26)
# 	at com.amazon.ws.emr.hadoop.fs.s3.lite.call.ListObjectsV2Call.perform(ListObjectsV2Call.java:12)
# 	at com.amazon.ws.emr.hadoop.fs.s3.lite.executor.GlobalS3Executor$CallPerformer.call(GlobalS3Executor.java:111)
# 	at com.amazon.ws.emr.hadoop.fs.s3.lite.executor.GlobalS3Executor.execute(GlobalS3Executor.java:138)
# 	at com.amazon.ws.emr.hadoop.fs.s3.lite.AmazonS3LiteClient.invoke(AmazonS3LiteClient.java:191)
# 	at com.amazon.ws.emr.hadoop.fs.s3.lite.AmazonS3LiteClient.invoke(AmazonS3LiteClient.java:186)
# 	at com.amazon.ws.emr.hadoop.fs.s3.lite.AmazonS3LiteClient.listObjectsV2(AmazonS3LiteClient.java:75)
# 	at com.amazon.ws.emr.hadoop.fs.s3n.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:414)
# 	... 52 more

# %% [markdown]
# Or if you want to separate it by the Senate and the House:

# %%
l_history.toDF().write.parquet('s3://jrbutbucketdest/new1', partitionBy=['org_name'])

# partitioning by the column value, partitionBy = ['org_name']. 
# We can also changed this to fit the needs, such as the partition the table on a monthly basis.

# %% [markdown]
# ### 6. Writing to Relational Databases
#
# AWS Glue makes it easy to write it to relational databases like Redshift even with
# semi-structured data. It offers a transform, `relationalize()`, that flattens DynamicFrames
# no matter how complex the objects in the frame may be.
#
# Using the `l_history` DynamicFrame in our example, we pass in the name of a root table
# (`hist_root`) and a temporary working path to `relationalize`, which returns a `DynamicFrameCollection`.
# We then list the names of the DynamicFrames in that collection:

# %%
dfc = l_history.relationalize("hist_root", "s3://jrbutbucketdest/")
dfc.keys()
# Out:
# dict_keys(['hist_root', 'hist_root_links', 'hist_root_images', 'hist_root_identifiers', 'hist_root_other_names', 'hist_root_contact_details'])

# %% [markdown]
# Relationalize broke the history table out into 6 new tables: a root table containing a record for each object in the
# dynamic frame, and auxiliary tables for the arrays. Array handling in relational databases is often sub-optimal,
# especially as those arrays become large. Separating out the arrays into separate tables makes the queries go much
# faster.
#
# Let's take a look at the separation by examining `contact_details`:

# %%
l_history.select_fields('contact_details').printSchema()
dfc.select('hist_root_contact_details').toDF().where("id = 10 or id = 75").orderBy(['id','index']).show()
# Out:
# root
# |-- contact_details: array
# |    |-- element: struct
# |    |    |-- type: string
# |    |    |-- value: string
#
# +---+-----+------------------------+-------------------------+
# | id|index|contact_details.val.type|contact_details.val.value|
# +---+-----+------------------------+-------------------------+
# | 10|    0|                     fax|             202-228-1820|
# | 10|    1|                   phone|             202-224-5623|
# | 10|    2|                 twitter|              SenDanCoats|
# | 75|    0|                     fax|             202-224-3416|
# | 75|    1|                   phone|             202-224-5744|
# | 75|    2|                 twitter|                SenShelby|
# +---+-----+------------------------+-------------------------+

# %% [markdown]
# The `contact_details` field was an array of structs in the original DynamicFrame.
# Each element of those arrays is a separate row in the auxiliary table, indexed by
# `index`. The `id` here is a foreign key into the `hist_root` table with the key
# `contact_details`.

# %%
dfc.select('hist_root').toDF().where("contact_details = 10 or contact_details = 75").select(['id', 'given_name', 'family_name', 'contact_details']).show()
# Out:
# +--------------------+----------+-----------+---------------+
# |                  id|given_name|family_name|contact_details|
# +--------------------+----------+-----------+---------------+
# |685acbe5-736d-43b...|    Daniel|      Coats|             10|
# |ee9a99d0-5d9a-467...|   Richard|     Shelby|             75|
# +--------------------+----------+-----------+---------------+

# %% [markdown]
# Notice in the commands above that we used `toDF()` and subsequently a `where` expression to filter for the rows that
# we wanted to see.
#
# So, joining the `hist_root` table with the auxiliary tables allows you to:
#
#  - Load data into databases without array support.
#  - Query each individual item in an array using SQL.
#
# We already have a connection set up called `redshift3`. To create your own, see
# [this topic in the Developer Guide](http://docs.aws.amazon.com/glue/latest/dg/populate-add-connection.html).
# Let's write this collection into Redshift by cycling through the DynamicFrames one at a time:

# %%
for df_name in dfc.keys():
        m_df = dfc.select(df_name)
        print("Writing to Redshift table: " + df_name)
        glueContext.write_dynamic_frame.from_jdbc_conf(frame = m_df,
                                                       catalog_connection = "redshift3",
                                                       connection_options = {"dbtable": df_name, "database": "testdb"},
                                                       redshift_tmp_dir = "s3://glue-sample-target/temp-dir/")

# %% [markdown]
# Notice in the commands above that we used `toDF()` and subsequently a `where` expression to filter for the rows that
# we wanted to see.
#
# So, joining the `hist_root` table with the auxiliary tables allows you to:
#
#  - Load data into databases without array support.
#  - Query each individual item in an array using SQL.
#
# We already have a connection set up called `redshift3`. To create your own, see
# [this topic in the Developer Guide](http://docs.aws.amazon.com/glue/latest/dg/populate-add-connection.html).
# Let's write this collection into Redshift by cycling through the DynamicFrames one at a time:
#
#     for df_name in dfc.keys():
#         m_df = dfc.select(df_name)
#         print("Writing to Redshift table: " + df_name)
#         glueContext.write_dynamic_frame.from_jdbc_conf(frame = m_df,
#                                                        catalog_connection = "redshift3",
#                                                        connection_options = {"dbtable": df_name, "database": "testdb"},
#                                                        redshift_tmp_dir = "s3://glue-sample-target/temp-dir/")
#
# Here's what the tables look like in Redshift. (We connected to Redshift through psql.)
#
#     testdb=# \d
#                        List of relations
#      schema |           name            | type  |   owner
#     --------+---------------------------+-------+-----------
#      public | hist_root                 | table | test_user
#      public | hist_root_contact_details | table | test_user
#      public | hist_root_identifiers     | table | test_user
#      public | hist_root_images          | table | test_user
#      public | hist_root_links           | table | test_user
#      public | hist_root_other_names     | table | test_user
#     (6 rows)
#
#     testdb=# \d hist_root_contact_details
#                  Table "public.hist_root_contact_details"
#               Column           |           Type           | Modifiers
#     ---------------------------+--------------------------+-----------
#      id                        | bigint                   |
#      index                     | integer                  |
#      contact_details.val.type  | character varying(65535) |
#      contact_details.val.value | character varying(65535) |
#
#     testdb=# \d hist_root
#                        Table "public.hist_root"
#             Column         |           Type           | Modifiers
#     -----------------------+--------------------------+-----------
#      role                  | character varying(65535) |
#      seats                 | integer                  |
#      org_name              | character varying(65535) |
#      links                 | bigint                   |
#      type                  | character varying(65535) |
#      sort_name             | character varying(65535) |
#      area_id               | character varying(65535) |
#      images                | bigint                   |
#      on_behalf_of_id       | character varying(65535) |
#      other_names           | bigint                   |
#      birth_date            | character varying(65535) |
#      name                  | character varying(65535) |
#      organization_id       | character varying(65535) |
#      gender                | character varying(65535) |
#      classification        | character varying(65535) |
#      legislative_period_id | character varying(65535) |
#      identifiers           | bigint                   |
#      given_name            | character varying(65535) |
#      image                 | character varying(65535) |
#      family_name           | character varying(65535) |
#      id                    | character varying(65535) |
#      death_date            | character varying(65535) |
#      start_date            | character varying(65535) |
#      contact_details       | bigint                   |
#      end_date              | character varying(65535) |
#
# Now you can query these tables using SQL in Redshift:
#
#     testdb=# select * from hist_root_contact_details where id = 10 or id = 75 order by id, index;
#
# With this result:
#
#      id | index | contact_details.val.type | contact_details.val.value
#     ----+-------+--------------------------+---------------------------
#      10 |     0 | fax                      |
#      10 |     1 |                          | 202-225-1314
#      10 |     2 | phone                    |
#      10 |     3 |                          | 202-225-3772
#      10 |     4 | twitter                  |
#      10 |     5 |                          | MikeRossUpdates
#      75 |     0 | fax                      |
#      75 |     1 |                          | 202-225-7856
#      75 |     2 | phone                    |
#      75 |     3 |                          | 202-225-2711
#      75 |     4 | twitter                  |
#      75 |     5 |                          | SenCapito
#     (12 rows)
#
#
# ### Conclusion
#
# Overall, AWS Glue is quite flexible allowing you to do in a few lines of code, what normally would take days to
# write. The entire source to target ETL scripts from end-to-end can be found in the accompanying Python file,
# [join_and_relationalize.py](join_and_relationalize.py).
